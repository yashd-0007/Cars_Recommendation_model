# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# Car Recommendation Model Loader\n",
    "This notebook loads the trained .pkl model and performs predictions."
   ]
  },
  {
   "cell_type": "code",
   "source": [
    "import pickle\n",
    "import pandas as pd\n",
    "import numpy as np\n",
    "\n",
    "MODEL_PATH = 'car_recommendation_model.pkl'"
   ],
   "metadata": {},
   "execution_count": null,
   "outputs": []
  },
  {
   "cell_type": "code",
   "source": [
    "# Load model\n",
    "with open(MODEL_PATH, 'rb') as f:\n",
    "    model = pickle.load(f)\n",
    "\n",
    "print('Model Loaded Successfully')\n",
    "print(type(model))"
   ],
   "metadata": {},
   "execution_count": null,
   "outputs": []
  },
  {
   "cell_type": "code",
   "source": [
    "# Example input\n",
    "user_data = {\n",
    "    'monthly_salary': 80000,\n",
    "    'budget': 1200000,\n",
    "    'fuel_type': 'Petrol',\n",
    "    'transmission': 'Automatic'\n",
    "}\n",
    "\n",
    "input_df = pd.DataFrame([user_data])\n",
    "input_df"
   ],
   "metadata": {},
   "execution_count": null,
   "outputs": []
  },
  {
   "cell_type": "code",
   "source": [
    "# Prediction\n",
    "prediction = model.predict(input_df)\n",
    "print('Recommended Car:', prediction)"
   ],
   "metadata": {},
   "execution_count": null,
   "outputs": []
  }
 ],
 "metadata": {
  "kernelspec": {
   "display_name": "Python 3",
   "language": "python",
   "name": "python3"
  },
  "language_info": {
   "name": "python",
   "version": "3.x"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 5
}
